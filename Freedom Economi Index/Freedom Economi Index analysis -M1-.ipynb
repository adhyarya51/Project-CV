# %% [markdown]
# Nama        : Adhy Arya Hendrata
#
# Objective   : saya akan melakukan analisis tentang "freedom economic index" dengan melakukan perbandingan, apa yang terjadi pada setiap negara.

# %% [markdown]
# Dataset : Freedom Economic Index , "([Url](https://www.kaggle.com/datasets/mlippo/freedom-economic-index/data?select=freedom_index.csv))"

# %% [markdown]
# Link Tablue : https://public.tableau.com/app/profile/adhy.arya.hendrata/viz/P1W1D4PM_17122396488970/Dashboard1?publish=yes

# %% [markdown]
# **Topik Permasalahan**
#
# - melakukan analisis ekonomi indeks negara dengan empat kategori terhadap setiap negara.

# %% [markdown]
# **Description :**
#
#     Kebebasan ekonomi menjadi fundamental hak untuk setiap manusia mengontrol atau memiliki lapangan kerja, dan properti. Pembahasan ekonomi di kebebasan masyarakat, setiap individu bebas untuk memilih pekerjaan, produksi, konsumsi, dan melakukan investasi dalam bentuk apapun. kebebasan ekonomi dalam bermasyarakat, pemerintah yang menciptakan lapangan kerja, kapital, dan industri bergerak bebas.
#
#     Perbedaan ekonomi dunia setiap tahun juga berbeda jauh dengan yang terjadi pada tahun 2024, salah satunya pengaruh konflik, politik antar negara memberikan perubahan jelas pada tahun ini. The Heritage Foundation (2023) menjelaskan untuk melakukan pengukuran kebebasan ekonomi ada empat yaitu : rule of law, government size, regulatory efficiency, dan open markets.
#
#     Indonesia menjadi negara yang bersangkutan dalam pendataan ekonomi indeks. bagaimana kondisi negara Indonesia ditahun 2024, saya akan melakukan analisis kepada negara, dan juga hasil analisis khususnya negara Indonesia.

# %% [markdown]
# metode : **SMART**

# %% [markdown]
# **Specific** : melakukan analisis penelitian terhadap data indeks negara, memiliki fokus sebagai analisis.
#
# **Measurable** : pengukuran "rule of law, government size, reglatory efficiency, dan open market", serta mengambil satu contoh negara sebagai contoh pengukuran situasi.
#
# **Achievable** : permasalahan dapat diselesaikan ketika bisa dilakukan proses identifikasi melakui keempat kategori.
#
# **Relevant** : pemahaman situasi ekonomi pada setiap negara adalah hal penting sebagai analisis data, pemangku kebijakan, akademisi, jurnalis, serta pembisnis, dan investor untuk mengetahui gambaran besar kondisi negara. hal tersebut akan menjadi fundamental untuk pengembangan ekonomi.
#
# **Time - Bound** : penyelesaian analisis dalam waktu telah ditentukan, serta memberikan pandangan baru kepada pemangku kebijakan dalam menentukan pengambilan keputusan.
#
# **SMART** : Analisis indeks ekonomi menggunakan empat pengukuran guna menentukan pengambilan keputusan kepada pihak perusahaan.

# %% [markdown]
# Penjabaran masalah dengan metode 5W + 1H

# %% [markdown]
#  Pengukuran kebebasan ekonomi memiliki empat kategori yaitu :
#
#     - Rule of law (property right, government integrity, judicial effectiveness) "rata2"
#
#     - Government Size (government spending, tax burden, fiscal health) "rata2"
#
#     - Regulatory Efficiency (business freedom, labor freedom, monetary freedom) "rata2"
#
#     - Open Markets (trade freedom, investment freedom, financial freedom) "Rata2"
#
# - Bagaimana urutan overall score based on negara ? (top 5)
# - pengukuran 5 negara terendah
# - region mana yang memiliki score tertinggi
# - pengukuran setiap rule of law based on negara
# - pengukuran setiap government size based on negara
# - pengukuran setiap negara regulatory efficiency based on negara
# - pengukuran setiap negara open markets based on negara
# - pengukuran negara ASEAN

# %% [markdown]
# ## Format

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from scipy import stats

# %% [markdown]
# ## A. Data Load

# %%
data = pd.read_csv('freedom_index.csv')

data
# Out:
#      Unnamed: 0      Country              Region  Year  Overall Score  \
# 0             0    Singapore        Asia-Pacific  2024           83.5
# 1             1  Switzerland              Europe  2024           83.0
# 2             2      Ireland              Europe  2024           82.6
# 3             3       Taiwan        Asia-Pacific  2024           80.0
# 4             4   Luxembourg              Europe  2024           79.2
# ..          ...          ...                 ...   ...            ...
# 171         171     Zimbabwe  Sub-Saharan Africa  2024           38.2
# 172         172        Sudan  Sub-Saharan Africa  2024           33.9
# 173         173    Venezuela            Americas  2024           28.1
# 174         174         Cuba            Americas  2024           25.7
# 175         175  North Korea        Asia-Pacific  2024            2.9
#
#      Property Rights  Government Integrity  Judicial Effectiveness  \
# ...

# %% [markdown]
# ## B. Data Cleaning

# %% [markdown]
# Data cleaning saya akan melakukan pembersihan kepada kolom yang tidak dibutuhkan :
#
# - pengecheckan missing value, dan pembersihan kepada nilai tidak valid.
# - melakukan pembersihan dan mengeluarkan data yang diperlukan.
# - merapikan format data type.

# %% [markdown]
# Mencari informasi data yang telah dipindahkan, memiliki tujuan untuk mencari informasi apa yang akan saya lihat didalam seluruh data.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176 entries, 0 to 175
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              176 non-null    int64
#  1   Country                 176 non-null    object
#  2   Region                  176 non-null    object
#  3   Year                    176 non-null    int64
#  4   Overall Score           176 non-null    float64
#  5   Property Rights         176 non-null    float64
#  6   Government Integrity    176 non-null    float64
#  7   Judicial Effectiveness  176 non-null    float64
#  8   Tax Burden              176 non-null    float64
#  9   Government Spending     176 non-null    float64
#  10  Fiscal Health           176 non-null    float64
#  11  Business Freedom        176 non-null    float64
#  12  Labor Freedom           176 non-null    float64
#  13  Monetary Freedom        176 non-null    float64
# ...

# %% [markdown]
# saya membuka kolom untuk mengetahui beberapa total jumlah kolom didata tersebut, saya menggunakan kolom tersebut sebagai referensi utama.

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Country', 'Region', 'Year', 'Overall Score',
#        'Property Rights', 'Government Integrity', 'Judicial Effectiveness',
#        'Tax Burden', 'Government Spending', 'Fiscal Health',
#        'Business Freedom', 'Labor Freedom', 'Monetary Freedom',
#        'Trade Freedom', 'Investment Freedom', 'Financial Freedom'],
#       dtype='object')

# %% [markdown]
# selanjutnya saya melakukan pengcheckan apakah ekspresi tidak berisi data yang valid (Null).

# %%
data.isnull().sum()
# Out:
# Unnamed: 0                0
# Country                   0
# Region                    0
# Year                      0
# Overall Score             0
# Property Rights           0
# Government Integrity      0
# Judicial Effectiveness    0
# Tax Burden                0
# Government Spending       0
# Fiscal Health             0
# Business Freedom          0
# Labor Freedom             0
# Monetary Freedom          0
# Trade Freedom             0
# Investment Freedom        0
# Financial Freedom         0
# dtype: int64

# %% [markdown]
# berdasarkan hasil tidak ada hasil nilai null, dan data tersebut sudah siap untuk memasuki tahap selanjutnya. Tahap selanjutnya saya menggunakan fungsi ```data = data.drop()``` bertujuan untuk menghapus kolom unnamed karena tidak akan dibutuhkan saat proses analisis.

# %%
data = data.drop(columns=['Unnamed: 0'])

# %%
data
# Out:
#          Country              Region  Year  Overall Score  Property Rights  \
# 0      Singapore        Asia-Pacific  2024           83.5             94.2
# 1    Switzerland              Europe  2024           83.0             94.2
# 2        Ireland              Europe  2024           82.6             93.5
# 3         Taiwan        Asia-Pacific  2024           80.0             82.2
# 4     Luxembourg              Europe  2024           79.2             96.9
# ..           ...                 ...   ...            ...              ...
# 171     Zimbabwe  Sub-Saharan Africa  2024           38.2             20.2
# 172        Sudan  Sub-Saharan Africa  2024           33.9             12.5
# 173    Venezuela            Americas  2024           28.1              0.0
# 174         Cuba            Americas  2024           25.7             30.1
# 175  North Korea        Asia-Pacific  2024            2.9             16.0
#
#      Government Integrity  Judicial Effectiveness  Tax Burden  \
# ...

# %% [markdown]
# selanjutnya saya memeriksa lagi data info untuk memastikan sekali lagi.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 176 entries, 0 to 175
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 176 non-null    object
#  1   Region                  176 non-null    object
#  2   Year                    176 non-null    int64
#  3   Overall Score           176 non-null    float64
#  4   Property Rights         176 non-null    float64
#  5   Government Integrity    176 non-null    float64
#  6   Judicial Effectiveness  176 non-null    float64
#  7   Tax Burden              176 non-null    float64
#  8   Government Spending     176 non-null    float64
#  9   Fiscal Health           176 non-null    float64
#  10  Business Freedom        176 non-null    float64
#  11  Labor Freedom           176 non-null    float64
#  12  Monetary Freedom        176 non-null    float64
#  13  Trade Freedom           176 non-null    float64
# ...

# %% [markdown]
# pada bagian ini saya menambahkan keempat kolom untuk kebutuhan analisis saya, dengan menambah empat kolom akan memudahkan saya melakukan analisis data.

# %%
# property right, government integrity, judicial effectiveness

data = pd.DataFrame(data)

Rule_of_Law = ['Property Rights', 'Government Integrity', 'Judicial Effectiveness']
data ['Rule of Law'] = data[Rule_of_Law].mean(axis=1)

# government spending, tax burden, fiscal health

Goverment_Size = ['Government Spending', 'Tax Burden', 'Fiscal Health']
data ['Government Size'] = data[Goverment_Size].mean(axis=1)

# business freedom, labor freedom, monetary freedom
  
Regulatory_Efficiency = ['Business Freedom', 'Labor Freedom', 'Monetary Freedom']
data ['Regulatory Efficiency'] = data[Regulatory_Efficiency].mean(axis=1)

# Trade freedom, Investment freedom, Financial freedom

Open_Markets = ['Trade Freedom', 'Investment Freedom', 'Financial Freedom']
data ['Open Markets'] = data[Open_Markets].mean(axis=1)

data.round(decimals=1)
# Out:
#          Country              Region  Year  Overall Score  Property Rights  \
# 0      Singapore        Asia-Pacific  2024           83.5             94.2
# 1    Switzerland              Europe  2024           83.0             94.2
# 2        Ireland              Europe  2024           82.6             93.5
# 3         Taiwan        Asia-Pacific  2024           80.0             82.2
# 4     Luxembourg              Europe  2024           79.2             96.9
# ..           ...                 ...   ...            ...              ...
# 171     Zimbabwe  Sub-Saharan Africa  2024           38.2             20.2
# 172        Sudan  Sub-Saharan Africa  2024           33.9             12.5
# 173    Venezuela            Americas  2024           28.1              0.0
# 174         Cuba            Americas  2024           25.7             30.1
# 175  North Korea        Asia-Pacific  2024            2.9             16.0
#
#      Government Integrity  Judicial Effectiveness  Tax Burden  \
# ...

# %% [markdown]
# pada part ini saya melakukan inisiasi untuk dengan memindahkan kebentuk csv, karena akan ada perbedaan data yang akan diolah. hal tersebut akan mempermudah diri saya untuk melakukan pemanggilan data saat melakukan pengolahan.

# %%
data.to_csv('freedom_index(cleaned)', index=False)

# %%
#Pengelompokan negara ASEAN 
# 'Indonesia','Malaysia', 'Singapura','Thailand','Filipina','Brunei Darussalam',
# 'Vietnam', 'Laos', 'Myanmar', 'Kamboja', 'Timor Leste'

ASEAN = pd.DataFrame()

ASEAN = data[(data["Country"] == "Indonesia") | (data["Country"] == "Malaysia") | 
             (data["Country"] == "Singapore") | (data["Country"] == "Thailand") |
             (data["Country"] == "The Philippines") | (data["Country"] == "Brunei Darussalam") |
             (data["Country"] == "Vietnam") | (data["Country"] == "Laos") |
             (data["Country"] == "Burma") |  (data["Country"] == "Cambodia") |
             (data["Country"] == "Timor-Leste")]

ASEAN.round(decimals=1)
# Out:
#                Country        Region  Year  Overall Score  Property Rights  \
# 0            Singapore  Asia-Pacific  2024           83.5             94.2
# 42   Brunei Darussalam  Asia-Pacific  2024           65.9             68.8
# 44            Malaysia  Asia-Pacific  2024           65.7             65.7
# 52           Indonesia  Asia-Pacific  2024           63.5             39.2
# 58             Vietnam  Asia-Pacific  2024           62.8             49.6
# 86     The Philippines  Asia-Pacific  2024           59.0             46.1
# 87            Thailand  Asia-Pacific  2024           59.0             45.0
# 105           Cambodia  Asia-Pacific  2024           55.6             41.0
# 141               Laos  Asia-Pacific  2024           50.6             44.0
# 142        Timor-Leste  Asia-Pacific  2024           50.2             39.9
# 166              Burma  Asia-Pacific  2024           42.2             18.0
#
#      Government Integrity  Judicial Effectiveness  Tax Burden  \
# ...

# %% [markdown]
# sama seperti data yang saya pisahkan untuk kumpulan negara "ASEAN", hal ini akan saya pindahkan kedalam bentuk file csv

# %%
ASEAN.to_csv('ASEAN', index=False)

# %%
ASEAN = ['Singapore', 'Brunei Darussalam' , 'Malaysia', 'Indonesia', 'Vietnam'
         'The Philippines' , 'Thailand' , 'Cambodia' , 'Laos' , 'Timor-Leste', 'Burma']

for Country in ASEAN :
    data = data.loc[data['Country'] != Country]

# %%
#pengcheckan negara2 yang dibutuhkan untuk melakukan ketikan remote.
data['Country'].unique()
# Out:
# array(['Switzerland', 'Ireland', 'Taiwan', 'Luxembourg', 'Denmark',
#        'Estonia', 'New Zealand', 'Norway', 'Sweden', 'Netherlands',
#        'Finland', 'Australia', 'South Korea', 'Lithuania', 'Canada',
#        'Cyprus', 'Germany', 'Latvia', 'Mauritius', 'Chile',
#        'United Arab Emirates', 'Iceland', 'Czech Republic', 'Israel',
#        'United States', 'Uruguay', 'Qatar', 'Portugal', 'United Kingdom',
#        'Bulgaria', 'Austria', 'Georgia', 'Jamaica', 'Slovakia',
#        'Botswana', 'Costa Rica', 'Japan', 'Croatia', 'Samoa', 'Barbados',
#        'Poland', 'Slovenia', 'Belgium', 'Armenia', 'Albania', 'Peru',
#        'Malta', 'Romania', 'Panama', 'Bahrain', 'Spain', 'Cabo Verde',
#        'Dominican Republic', 'Oman', 'Vietnam', 'Serbia', 'The Bahamas',
#        'France', 'Guatemala', 'Saint Lucia', 'Vanuatu',
#        'Bosnia and Herzegovina', 'Kazakhstan', 'Mexico', 'Saudi Arabia',
#        'Azerbaijan', 'North Macedonia', 'Belize', 'Hungary', 'Micronesia',
# ...

# %% [markdown]
# saya melakukan pemisahan file untuk mempermudah dalam membandingkan kedua bentuk data yang berbeda.

# %%
#pemindahan data csv non asean kedalam bentuk file
data.to_csv('Freedom_index(non ASEAN)', index=False)

# %%
#pemindahan data csv keseluruhan untuk kepentingan data tableu
data.to_csv('Milestone1-Adhy-Arya-Tableu',index=False)

# %% [markdown]
# ## C. Analisis dan Perhitungan

# %% [markdown]
# selanjutanya saya melakukan penggambaran atau mendeskripsikan data berdasarkan hasil yang saya peroleh dari data cleaning.

# %%
#pemanggilan data yang sudah dicleaning untuk analisis dan perhitungan
dataCleaned = pd.read_csv('freedom_index(cleaned)')

# %% [markdown]
# ##### Statistik Deskriptif

# %%
#menghitung rata - rata nilai keseluruhan
mean_overall_score = dataCleaned['Overall Score'].mean()
#menghitungan median nilai keseluruhan
median_overall_score = dataCleaned['Overall Score'].median()
#menghitung mode nilai keseluruhan
mode_overall_score = dataCleaned['Overall Score'].mode()

print('Rata - rata score keseluruhan negara :', mean_overall_score)
print('median score keseluruhan negara :', median_overall_score)
print('mode score keseluruhan negara :', mode_overall_score)
# Out:
# Rata - rata score keseluruhan negara : 58.64318181818182
# median score keseluruhan negara : 58.8
# mode score keseluruhan negara : 0    62.0
# 1    62.9
# 2    77.8
# Name: Overall Score, dtype: float64

# %% [markdown]
# Dari data diatas ditemukan rata - rata score negara sebesar 58,64 persen.

# %% [markdown]
# setelah itu saya mengecheck dengan fungsi ```dataCleaned.describe()``` dengan tujuan untuk membutuhkan referensi dalam perhitungan statistik.

# %%
dataCleaned.describe()
# Out:
#          Year  Overall Score  Property Rights  Government Integrity  \
# count   176.0     176.000000       176.000000            176.000000
# mean   2024.0      58.643182        54.589205             44.428977
# std       0.0      11.153232        24.276600             21.554134
# min    2024.0       2.900000         0.000000              3.600000
# 25%    2024.0      51.975000        37.275000             28.100000
# 50%    2024.0      58.800000        49.500000             40.900000
# 75%    2024.0      65.750000        72.550000             58.475000
# max    2024.0      83.500000       100.000000             97.400000
#
#        Judicial Effectiveness  Tax Burden  Government Spending  Fiscal Health  \
# count              176.000000  176.000000           176.000000     176.000000
# mean                49.803977   78.104545            64.036932      52.180682
# std                 26.960768   12.917947            25.186746      33.724461
# ...

# %%
skewness_overall_score = dataCleaned['Overall Score'].skew()

print('skewness score keseluruhan :', skewness_overall_score)
# Out:
# skewness score keseluruhan : -0.7285335314831373

# %% [markdown]
# menjadi sebuah catatan untuk mengetahui distribusi data seperti
#
# - Normal : -0.5 s/d 0.5
# - Skewness : -1 s/d -0.5 atau 0.5 s/d 1
# - Highly Skew/Extreme : <-1 atau >1

# %% [markdown]
# saya melakukan tes skewness ditemukan didalam skor keseluruhan bahwa data tidak terdistribusi secara normal, dan menghasilkan skewness negatif namun dalam part ini saya akan mengabaikan karena data tersebut tidak akan berpengaruh besar.

# %% [markdown]
# ##### Statistik Inferensial

# %% [markdown]
# didalam statistik inferensial saya akan menggunakan confidence interval.

# %%
dataCleaned = pd.DataFrame(dataCleaned)

# Sub-Saharan Africa          
# Europe                      
# Asia-Pacific                
# Americas                    
# Middle East/North Africa 

SubSaharanOverall = dataCleaned[dataCleaned['Region']=='Sub-Saharan Africa']['Overall Score']
EuropeOverall = dataCleaned[dataCleaned['Region']=='Europe']['Overall Score']
AsiaPacificOverall = dataCleaned[dataCleaned['Region']=='Asia-Pacific']['Overall Score']
AmericasOverall = dataCleaned[dataCleaned['Region']=='Americas']['Overall Score']
MiddleEastNorthAfricaOverall = dataCleaned[dataCleaned['Region']=='Middle East/North Africa']['Overall Score']

#dalam part ini saya mencoba melakukan perhitungan dalam pengelompokan

mean_sub = np.mean(SubSaharanOverall)
std_sub = np.std(SubSaharanOverall)

mean_euro = np.mean(EuropeOverall)
std_euro = np.std(EuropeOverall)

mean_asia = np.mean(AsiaPacificOverall)
std_asia = np.std(AsiaPacificOverall)

mean_america = np.mean(AmericasOverall)
std_america = np.std(AmericasOverall)

mean_middle = np.mean(MiddleEastNorthAfricaOverall)
std_middle = np.std(MiddleEastNorthAfricaOverall)


#perhitungan saya lakukan masing - masing kelompok dan keseluruhan dengan tingkat kepercayaan 95%
conf_int_sub = stats.norm.interval(0.95,loc=mean_sub,scale=std_sub/np.sqrt(len(SubSaharanOverall)))
conf_int_euro = stats.norm.interval(0.95,loc=mean_euro,scale=std_euro/np.sqrt(len(EuropeOverall)))
conf_int_asia = stats.norm.interval(0.95,loc=mean_asia,scale=std_asia/np.sqrt(len(AsiaPacificOverall)))
conf_int_america = stats.norm.interval(0.95,loc=mean_america,scale=std_america/np.sqrt(len(AmericasOverall)))
conf_int_middle = stats.norm.interval(0.95,loc=mean_middle,scale=std_middle/np.sqrt(len(MiddleEastNorthAfricaOverall)))

print('Confidence Interval dalam pengukuran region sub saharan africa : ', conf_int_sub)
print('Confidence Interval dalam pengukuran region eropa :', conf_int_euro)
print('Confident Interval dalam pengukuran region asia pacific :', conf_int_asia)
print('Confident Interval dalam pengukuran region america :', conf_int_america)
print('Confident Interval dalam pengukuran region middle east and north africa :', conf_int_middle)
# Out:
# Confidence Interval dalam pengukuran region sub saharan africa :  (50.39905036102654, 54.5115879368458)
# Confidence Interval dalam pengukuran region eropa : (64.87250190705409, 69.50477082021864)
# Confident Interval dalam pengukuran region asia pacific : (53.341553120529944, 61.52511354613673)
# Confident Interval dalam pengukuran region america : (54.28547131718227, 61.708278682817735)
# Confident Interval dalam pengukuran region middle east and north africa : (52.50009964779849, 62.31418606648721)

# %% [markdown]
# Dari hasil confidence interval untuk setiap kolom perhitungan, dapat disimpulkan menjadi beberapa yaitu :
#
# 1. Sub Saharan Africa : Confidence interval untuk rata rata region antara 50,399 dan 54,511 dengan tingkat kepercayaan 95%.
#
# 2.  Europe : Confidence interval untuk rata rata region antara 64,872 dan 69,504 dengan tingkat kepercayaan 95%.
#
# 3.  Asia Pacific : Confidence interval untuk rata rata region antara 53,34 dan 61,52 dengan tingkat kepercayaan 95%.
#
# 4.  America : Confidence interval untuk rata rata region antara 54,285 dan 61,708 dengan tingkat kepercayaan 95%.
#
# 5.  middle east and north africa : Confidence interval untuk rata rata region antara 52,500 dan 62,314 dengan tingkat kepercayaan 95%.
#
# Dari hasil tersebut dilihat masing - masing region memiliki nilai yang mendekati satu sama lain, dengan region tertinggi pada wilayah europe. kita memiliki keyakinan bahwa setiap region memiliki kisaran confidence interval yang diberikan.

# %% [markdown]
# ##### Hypothesis Testing

# %% [markdown]
# pada bagian ini saya menggunakan metode ```two simple independent test``` dengan melakukan perbandingan antara negara ASEAN dan negara non ASEAN.
# Test tersebut bertujuan untuk mengetes dua kondisi. saya menggunakan modul ```scipy.stats```, dan akan melakukan pengukuran pada nilai p-value dengan standart perhitungan 0,05.
#
# - H0 : nilai overall score negara ASEAN == nilai overall score negara non ASEAN
# - H1 : nilai overall score negara ASEAN != nilai overall score negara non ASEAN

# %%
#melakukan pemindahan data csv untuk mempermudah pemanggilan
dataNonASEAN = pd.read_csv('Freedom_index(non ASEAN)')
dataASEAN = pd.read_csv('ASEAN')

# %%
print('Rata - rata overall score negara nonASEAN =',dataNonASEAN['Overall Score'].mean())
print('Rata - rata overall score negara ASEAN =',dataASEAN['Overall Score'].mean())
# Out:
# Rata - rata overall score negara nonASEAN = 58.59281437125748
# Rata - rata overall score negara ASEAN = 59.81818181818183

# %%
#perhitungan T statistic dan P value
t_stat, p_val = stats.ttest_ind(dataASEAN['Overall Score'],dataNonASEAN['Overall Score'])
print('T-statistic:',t_stat)
print('P-value',p_val)
# Out:
# T-statistic: 0.3539399452397433
# P-value 0.7238075423008028

# %% [markdown]
# Dari hasil yang ditemukan bahwa score didapatkan memiliki keterhubungan satu sama lain, dan memiliki hubungan secara positif dengan dibuktikan hasil data p-value > 0.05.

# %% [markdown]
# ##### Visualisasi Data

# %% [markdown]
# pada visualisasi data pertama saya akan melakukan pengecheckan tabel yang akan dilakukan visualisasi.

# %%
dataCleaned.head()
# Out:
#        Country        Region  Year  Overall Score  Property Rights  \
# 0    Singapore  Asia-Pacific  2024           83.5             94.2
# 1  Switzerland        Europe  2024           83.0             94.2
# 2      Ireland        Europe  2024           82.6             93.5
# 3       Taiwan  Asia-Pacific  2024           80.0             82.2
# 4   Luxembourg        Europe  2024           79.2             96.9
#
#    Government Integrity  Judicial Effectiveness  Tax Burden  \
# 0                  88.3                    58.3        90.7
# 1                  91.3                    98.1        70.4
# 2                  83.4                    94.3        78.0
# 3                  73.4                    94.0        79.2
# 4                  84.9                    95.8        64.6
#
#    Government Spending  Fiscal Health  Business Freedom  Labor Freedom  \
# 0                 89.2           76.0              86.9           77.3
# ...

# %%
#menghitung kondisi tabel region dan jumlah negara didalamnya
region_freq = dataCleaned['Region'].value_counts()
region_freq
# Out:
# Region
# Sub-Saharan Africa          47
# Europe                      44
# Asia-Pacific                39
# Americas                    32
# Middle East/North Africa    14
# Name: count, dtype: int64

# %%
#melakukan pemanggilan bar dengan melihat jumlah negara masing2 region
region_freq.plot(kind='bar')
# Out:
# <Axes: xlabel='Region'>

# %%
# mencoba melakukan grouping untuk top5 negara, negara terendah, dan region chart
top5negara = dataCleaned.head(5)
negaraterendah = dataCleaned.tail(5)
regionchart = dataCleaned.groupby(['Region'])['Overall Score'].mean().reset_index()

# %% [markdown]
# ###### Top 5 rule of law Country

# %%
#menghitung pengukuran rule of law untuk top 5 negara
ruleoflawcountry = dataCleaned.sort_values(by='Rule of Law', ascending=False)
ruleoflawcountry5 = ruleoflawcountry.head(5)
#menghitung pengukuran government size untuk top 5 negara
governmentsize = dataCleaned.sort_values(by='Government Size', ascending=False)
governmentsize5 = governmentsize.head(5)
#menghitung pengukuran regulatory efficiency untuk top 5 negara
regulatoryefficiency = dataCleaned.sort_values(by='Regulatory Efficiency', ascending=False)
regulatoryefficiency5 = regulatoryefficiency.head(5)
#menghitung pengukuran open markets untuk top 5 negara
openmarkets = dataCleaned.sort_values(by='Open Markets', ascending=False)
openmarkets5 = openmarkets.head(5)
#melakukan perhitungan keseulurahan untuk negara ASEAN
AseanOverall = dataASEAN.sort_values(by='Overall Score', ascending=False)
AseanOverall10 = AseanOverall.head(11)

# %% [markdown]
# ###### top 5 urutan negara dengan overal score tertinggi

# %%
#plotting
plt.figure(figsize=(12, 5))
sns.barplot(x='Country', y='Overall Score', data=top5negara)
plt.title('Total Overall Score Country')
plt.xlabel('Country')
plt.ylabel('Total Score')
plt.show()

# %% [markdown]
# dari tabel informasi diatas bar chart menunjukan 5 negara tertinggi dalam score keseluruhan.

# %% [markdown]
# ###### 5 negara terendah

# %%
#plotting
plt.figure(figsize=(12, 5))
sns.barplot(x='Country', y='Overall Score', data=negaraterendah)
plt.title('Total Overall Score Negara terendah')
plt.xlabel('Country')
plt.ylabel('Total Score')
plt.show()

# %% [markdown]
# berikut adalah hasil 5 chart negara terendah berdasakan score secara keseluruhan, dilihat dari chat bahwa zimbabwe,sudan,venezual, cuba, dan north korea.

# %% [markdown]
# setelah ini saya akan melakukan proses data visualisasi dengan overal score setiap region

# %% [markdown]
# ###### total overall score region

# %%
#plotting
plt.figure(figsize=(10, 6))
sns.barplot(x='Region', y='Overall Score', data=regionchart)
plt.title('Total Overall Score Region')
plt.xlabel('Region')
plt.ylabel('Total Score')
plt.show()

# %% [markdown]
# dari bar chart diatas dapat disimpulkan setiap region memiliki score yang mendekati. hanya region europe yang tertinggi dari lainnya.

# %% [markdown]
# ###### top 5 rule of law

# %%
#plotting
plt.figure(figsize=(10, 6))
sns.barplot(x='Country', y='Rule of Law', data=ruleoflawcountry5)
plt.title('Rule of Law')
plt.xlabel('Country')
plt.ylabel('Rule of Law')
plt.show()

# %% [markdown]
# dari data diatas disimpulkan bahwa rata rule of law setiap negara finland menjadi yang tertinggi, diikuti oleh negara norway, denmark, sweden, dan switzerland.

# %% [markdown]
# ###### top 5 government size

# %%
#plotting
plt.figure(figsize=(10, 6))
sns.barplot(x='Country', y='Government Size', data=governmentsize5)
plt.title('Government Size')
plt.xlabel('Country')
plt.ylabel('Government Size')
plt.show()

# %% [markdown]
# dari data bar charts untuk government size, negara turkmenistan menjadi tertinggi, diikuti oleh UAE, guantemala, qatar, dan haiti.

# %% [markdown]
# ###### top 5 Regulatory Efficiency

# %%
#plotting
plt.figure(figsize=(10, 6))
sns.barplot(x='Country', y='Regulatory Efficiency', data=regulatoryefficiency5)
plt.title('Regulatory Efficiency')
plt.xlabel('Country')
plt.ylabel('Regulatory Efficiency')
plt.show()

# %% [markdown]
# dari data bar charts regulatory efficiency bahwa negara singapore menjadi yang tertinggi, diikuti oleh negara, singapore, united states, austria, taiwan, dan new zealand.

# %% [markdown]
# ###### top 5 negara open markets

# %%
#plotting
plt.figure(figsize=(10, 6))
sns.barplot(x='Country', y='Open Markets', data=openmarkets5)
plt.title('Open Markets')
plt.xlabel('Country')
plt.ylabel('Open Markets')
plt.show()

# %% [markdown]
# dari data bar charts diatas untuk kategori open markets, ditemukan bahwa negara singapore menjadi yang pertama, diikuti oleh australia, luxembourg, switzerland, dan bahrain.

# %% [markdown]
# ###### Overall score negara ASEAN

# %%
#plotting
plt.figure(figsize=(12, 5))
sns.barplot(x='Country', y='Overall Score', data=AseanOverall10)
plt.title('Total Overall Score ASEAN')
plt.xlabel('ASEAN')
plt.ylabel('Total Score')
plt.show()

# %% [markdown]
# bar chart yang terakhir saya ingin menunjukan situasi pada negara ASEAN, dalam hal ini singapore menjadi peringkat pertama untuk skor secara menyeluruh. informasi tambahan seperti Indonesia menjadi peringkat keempat untuk keseluruhan ASEAN, sedangkan Burma menjadi urutan terendah untuk skor secara menyeluruh.

# %% [markdown]
# ## Pengambilan Kesimpulan

# %% [markdown]
# berdasarkan hasil analisis data saya dapat menyimpulkan dengan temuan saya bahwa :
#
# 1. **Negara dengan top 5 overall score tertinggi** : kota dengan overal score tertinggi adalah negara ```Singapore``` dengan persentase rata - rata tertinggi. Hal ini menunjukan bahwa negara memiliki tingkat investasi, konsumsi, dan tenaga kerja. namun dalam beberapa kasus hal tersebut bisa diikuti dengan inflasi tinggi.
#
# 2. **Negara dengan 5 overall score terendah** : kota dengan overal score terendah adalah ```korea utara``` dengan persentase rata - rata rendah. Hal ini berupa kebalikan dari negara tertinggi, lokasi negara tidak akan menjadi target investasi, apalagi untuk melakukan ekspansi lebih besar, tidak rekomendasi untuk melakukan hal tersebut.
#
# 3. **Region yang memiliki score tertinggi** : untuk kisaran region dilihat semua memiliki score yang mendekati namun region paling tingga ada pada region eropa. disimpulkan bahwa mayoritas negara - negara eropa memiliki kebebasan ekonomi lebih besar dari region lainnya.
#
# 4. **Pengukuran rule of law tertinggi negara** : alasan melakukan pengukuran rule of law untuk melihat sebera kuat hukum setiap suatu negara. berdasarkan visualisasi negara finlandia memiliki nilai terkuat, dengan melakukan perhitungan pada ```property right, government integrity, judicial effectiveness```
#
# 5. **Pengukuran Government Size tertinggi negara** : dalam tingkat government size terhadap chart yang di analisa bahwa turkmenistan menjadi peringkat paling tinggi, dan hal yang menarik adalah kelima negara termasuk negara bagian timur tengah. Negara negara tersebut memiliki tingkat pengeluaran negara besar, dengan kata lain negara menunjukan perkembangan ekonomi, dan distribusi barang - barang. Namun, pajak negara kemungkinan tinggi, hal tersebut bisa dijadikan bahan pertimbangan oleh perusahaan.
#
# 6. **Pengukuran Regulatory Efficiency negara** : berdasarkan grafik yang ditunjukan pengukuran kebijakan suatu negara, bagaimana transparasi yang diberikan melalui aturan negara. Singapur menjadi peringkat pertama, mencapai 80% pada hasil grafik tersebut.
#
# 7. **Pengukuran Open Markets negara** : pasar terbuka negara yang efisien memberikan perkembangan ekonomi sehat dan bisa memberikan pertumbuhan kelanjutan karena akan memberikan akses luas kepada investor. hal ini negara singapur sebagai peringkat teratas dalam open market bisa menjadi bahan pertimbang perusahaan.
#
# 8. **Pengukuran negara ASEAN** : data visualisasi terakhir saya memeriksa dengan negara - negara ASEAN dengan alasan melihat kondisi negara sekita. Diketahui bahwa singapur masih paling tinggi, khususnya Indonesia menjadi perangkat 4. Indonesia masih memiliki potensi untuk menjadi tempat ekspansi perusahaan.
#
#
# Hasil dari keseluruhan data yang dilakukan, saya merekomendasikan kepada pihak perusahaan untuk memperhatikan faktor - faktor apabila memiliki rencana untuk melakukan ekspansi. Memperhatikan investasi wilayah negara dengan pasar terbuka negara, perusahaan bisa memiliki target pada peringkat negara tertinggi. Namun, perlu diperhatikan seperti cost sumber daya manusia bisa diperhatikan setiap negara. Ekspansi perusahaan serta overal cost untuk perusahaan ekspansi bisa diperhatikan untuk target kinerja perusahaan kedepannya.
